# %%
#Required Packages
import numpy as np #The Numpy numerical computing library
import pandas as pd #The Pandas data science library
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

#reading data 
df=pd.read_csv("Northwestern_data.csv")
df=df.reset_index(drop=True)

#Rename columns and deleting year 1999
df = df.rename(columns={'Unnamed: 0': 'Year'})
df.drop(['1999'], axis=1)

print(df.dtypes)
print(df)

for i in range (2000, 2019):
    plt.plot(df[str(i)])
# Out:
# Year    object
# 1999    object
# 2000    object
# 2001    object
# 2002    object
# 2003    object
# 2004    object
# 2005    object
# 2006    object
# 2007    object
# 2008    object
# 2009    object
# 2010    object
# 2011    object
# 2012    object
# 2013    object
# 2014    object
# 2015    object
# 2016    object
# 2017    object
# 2018    object
# 2019    object
# dtype: object
#                                       Year   1999   2000   2001   2002   2003  \
# 0                Education & Social Policy    259    267    297    307    277
# 1                        Medill Journalism    627    613    617    638    658
# 2                 Weinberg Arts & Sciences  3,849  3,708  3,817  3,933  3,840
# 3                             Bienen Music    406    409    392    380    383
# 4                            Communication  1,170  1,133  1,119  1,102  1,102
# 5                    McCormick Engineering  1,410  1,405  1,427  1,398  1,385
# 6  TOTAL FULL-TIME EVANSTON UNDERGRADUATES  7,721  7,535  7,669  7,758  7,645
#
#     2004   2005   2006   2007  ...   2010   2011   2012   2013   2014   2015  \
# 0    259    243    261    275  ...    362    377    392    405    401    390
# 1    655    663    669    681  ...    681    682    674    677    655    613
# 2  4,070  4,009  4,058  4,149  ...  4,314  4,316  4,252  4,176  4,023  3,948
# 3    397    402    404    408  ...    409    385    389    372    352    367
# 4  1,146  1,166  1,203  1,193  ...  1,149  1,165  1,117  1,096  1,132  1,051
# 5  1,313  1,343  1,381  1,394  ...  1,452  1,496  1,552  1,623  1,700  1,764
# 6  7,840  7,826  7,976  8,100  ...  8,367  8,421  8,376  8,349  8,263  8,133
#
#     2016   2017   2018   2019
# 0    395    431    492    492
# 1    633    626    648    684
# 2  3,911  3,857  3,726  3,795
# 3    390    371    373    376
# 4  1,039  1,007  1,004  1,014
# 5  1,848  1,825  1,812  1,801
# 6  8,216  8,117  8,055  8,162
#
# [7 rows x 22 columns]
